# %%
import intake

# %%
intake.gui.add('http://nginx/intake-catalogs/Treffen.yaml')
# Out:
# WARNING:param.MultiSelect: Use method 'set_param' via param namespace

# %%
intake.gui
# Out:
# Column(width_policy='max')
#     [0] Row(width_policy='max')
#         [0] PNG(str)
#         [1] Column(width_policy='max')
#             [0] Column(name='Select Catalog')
#                 [0] Markdown(str, max_height=40)
#                 [1] MultiSelect(min_width=200, options={'builtin': <Intake catalo...}, size=9, value=[<Intake catalog: T...], width_policy='min')
#             [1] Row(name='Controls')
#                 [0] Toggle(name='＋', width=50)
#                 [1] Button(clicks=3, name='―', width=50)
#                 [2] Toggle(name='🔍', width=50)
#         [2] Column(width_policy='max')
#             [0] Column(name='Select Data Source')
#                 [0] Markdown(str, max_height=40)
#                 [1] MultiSelect(min_width=200, options=OrderedDict([('json', ...]), size=9, value=[name: json
# container: xar...], width_policy='min')
#             [1] Row(name='Controls')
#                 [0] Toggle(name='📊', width=50)
# ...

# %%
intake.gui.item().read_chunked()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [11], in <cell line: 1>()
# ----> 1 intake.gui.item().read_chunked()
#
# File /opt/conda/lib/python3.9/site-packages/intake_xarray/base.py:44, in DataSourceMixin.read_chunked(self)
#      42 def read_chunked(self):
#      43     """Return xarray object (which will have chunks)"""
# ---> 44     self._load_metadata()
#      45     return self._ds
#
# File /opt/conda/lib/python3.9/site-packages/intake/source/base.py:236, in DataSourceBase._load_metadata(self)
#     234 """load metadata only if needed"""
#     235 if self._schema is None:
# --> 236     self._schema = self._get_schema()
#     237     self.dtype = self._schema.dtype
#     238     self.shape = self._schema.shape
#
# File /opt/conda/lib/python3.9/site-packages/intake_xarray/base.py:18, in DataSourceMixin._get_schema(self)
# ...
