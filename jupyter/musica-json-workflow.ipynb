# %%
from fsspec_reference_maker.hdf import SingleHdf5ToZarr 
from fsspec_reference_maker.combine import MultiZarrToZarr

import xarray as xr
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt
import s3fs
import logging
import fsspec
import json
import ujson

from tqdm import tqdm
from glob import glob

# %%
input_path = '/home/jovyan/work/input/MUSICA/IASIA_MUSICA_030301_L2_AllTargetProducts_20210103214757_73737.nc';
output_path = '/home/jovyan/work/output/MUSICA/IASIA_MUSICA_030301_L2_AllTargetProducts_20210103214757_73737.nc.json';
    
with fsspec.open(input_path, 'rb') as f:
        h5chunks = SingleHdf5ToZarr(f, input_path, inline_threshold=300)

        with open(output_path, 'wb') as outf:
            outf.write(ujson.dumps(h5chunks.translate()).encode())
# Out:
# /opt/conda/lib/python3.9/site-packages/zarr/storage.py:431: FutureWarning: missing object_codec for object array; this will raise a ValueError in version 3.0
#   warnings.warn('missing object_codec for object array; this will raise a '
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 4>()
#       5 h5chunks = SingleHdf5ToZarr(f, input_path, inline_threshold=300)
#       7 with open(output_path, 'wb') as outf:
# ----> 8     outf.write(ujson.dumps(h5chunks.translate()).encode())
#
# File /opt/conda/lib/python3.9/site-packages/fsspec_reference_maker/hdf.py:73, in SingleHdf5ToZarr.translate(self)
#      71 lggr.debug('Translation begins')
#      72 self._transfer_attrs(self._h5f, self._zroot)
# ---> 73 self._h5f.visititems(self._translator)
#      74 if self.inline > 0:
#      75     self._do_inline(self.inline)
#
# ...

# %% [markdown]
# Using the exact parameters from https://medium.com/pangeo/fake-it-until-you-make-it-reading-goes-netcdf4-data-on-aws-s3-as-zarr-for-rapid-data-access-61e33f8fe685.

# %%
input_path = '/home/jovyan/work/input/MUSICA/IASIA_MUSICA_030301_L2_AllTargetProducts_20210103214757_73737.nc';
output_path = '/home/jovyan/work/output/MUSICA/IASIA_MUSICA_030301_L2_AllTargetProducts_20210103214757_73737.nc.json';
    
with fsspec.open(input_path, 'rb', default_fill_cache=False, default_cache_type="none") as f:
        h5chunks = SingleHdf5ToZarr(f, input_path, inline_threshold=300)

        with open(output_path, 'wb') as outf:
            outf.write(ujson.dumps(h5chunks.translate()).encode())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 4>()
#       5 h5chunks = SingleHdf5ToZarr(f, input_path, inline_threshold=300)
#       7 with open(output_path, 'wb') as outf:
# ----> 8     outf.write(ujson.dumps(h5chunks.translate()).encode())
#
# File /opt/conda/lib/python3.9/site-packages/fsspec_reference_maker/hdf.py:73, in SingleHdf5ToZarr.translate(self)
#      71 lggr.debug('Translation begins')
#      72 self._transfer_attrs(self._h5f, self._zroot)
# ---> 73 self._h5f.visititems(self._translator)
#      74 if self.inline > 0:
#      75     self._do_inline(self.inline)
#
# File /opt/conda/lib/python3.9/site-packages/h5py/_hl/group.py:613, in Group.visititems(self, func)
#     611     name = self._d(name)
#     612     return func(name, self[name])
# --> 613 return h5o.visit(self.id, proxy)
#
# ...
